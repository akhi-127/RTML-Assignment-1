# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Preprocess the data by reshaping and scaling
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# Define a multi-layer perceptron model using sequential API
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model with Adam optimizer and sparse categorical crossentropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model for 20 epochs and validate on test data
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))

# Plot the loss and accuracy during training and validation
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()

# Save the model and its trained parameters
model.save('fashion_mnist_mlp.h5')
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.4803 - accuracy: 0.8258 - val_loss: 0.4358 - val_accuracy: 0.8429
# Epoch 2/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3632 - accuracy: 0.8668 - val_loss: 0.3767 - val_accuracy: 0.8635
# Epoch 3/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3264 - accuracy: 0.8794 - val_loss: 0.3588 - val_accuracy: 0.8704
# Epoch 4/20
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3026 - accuracy: 0.8890 - val_loss: 0.3647 - val_accuracy: 0.8686
# Epoch 5/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2868 - accuracy: 0.8922 - val_loss: 0.3433 - val_accuracy: 0.8732
# Epoch 6/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2699 - accuracy: 0.8986 - val_loss: 0.3518 - val_accuracy: 0.8759
# Epoch 7/20
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Preprocess the data
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0
# Define the model
model = tf.keras.models.Sequential([
 tf.keras.layers.Dense(512, activation='relu',
 kernel_regularizer=tf.keras.regularizers.l2(0.01), input_shape=(784
,)),
 tf.keras.layers.Dense(256, activation='relu',
 kernel_regularizer=tf.keras.regularizers.l2(0.01)),
 tf.keras.layers.Dense(128, activation='relu',
 kernel_regularizer=tf.keras.regularizers.l2(0.01)),
 tf.keras.layers.Dense(10, activation='softmax')
])
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
 metrics=['accuracy'])
# Train the model
history = model.fit(x_train, y_train, epochs=20, validation_data=(
x_test, y_test))
# Plot the results
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.show()
# Save the trained parameters and model
model.save('fashion_mnist_mlp_l2.h5')
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 21s 11ms/step - loss: 1.2841 - accuracy: 0.7743 - val_loss: 0.9864 - val_accuracy: 0.6931
# Epoch 2/20
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.7645 - accuracy: 0.8024 - val_loss: 0.7536 - val_accuracy: 0.8014
# Epoch 3/20
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.6996 - accuracy: 0.8156 - val_loss: 0.6824 - val_accuracy: 0.8224
# Epoch 4/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.6664 - accuracy: 0.8253 - val_loss: 0.7098 - val_accuracy: 0.7947
# Epoch 5/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.6419 - accuracy: 0.8273 - val_loss: 0.6847 - val_accuracy: 0.8028
# Epoch 6/20
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.6313 - accuracy: 0.8299 - val_loss: 0.6545 - val_accuracy: 0.8200
# Epoch 7/20
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test)= tf.keras.datasets.fashion_mnist.load_data()
# Preprocess the data
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0
# Define the model
model = tf.keras.models.Sequential([
 tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)),
 tf.keras.layers.Dropout(0.3),
 tf.keras.layers.Dense(64, activation='relu'),
 tf.keras.layers.Dropout(0.3),
 tf.keras.layers.Dense(32, activation='relu'),
 tf.keras.layers.Dropout(0.3),
 tf.keras.layers.Dense(10, activation='softmax')
])
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
 metrics=['accuracy'])
# Train the model
history = model.fit(x_train, y_train, epochs=20, validation_data=(
x_test, y_test))
# Plot the training results
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
plt.plot(history.history['loss'], label='training loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7801 - accuracy: 0.7215 - val_loss: 0.5196 - val_accuracy: 0.8214
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5401 - accuracy: 0.8135 - val_loss: 0.4498 - val_accuracy: 0.8381
# Epoch 3/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4960 - accuracy: 0.8288 - val_loss: 0.4159 - val_accuracy: 0.8509
# Epoch 4/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.4651 - accuracy: 0.8387 - val_loss: 0.3894 - val_accuracy: 0.8592
# Epoch 5/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4456 - accuracy: 0.8471 - val_loss: 0.3863 - val_accuracy: 0.8601
# Epoch 6/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4277 - accuracy: 0.8510 - val_loss: 0.3767 - val_accuracy: 0.8625
# Epoch 7/20
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))

# Save the weights
model.save_weights("model_weights.h5")

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test, verbose=False)
print("Test Accuracy: {:.4f}".format(accuracy))

# Plot the training results
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4882 - accuracy: 0.8267 - val_loss: 0.4105 - val_accuracy: 0.8533
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3647 - accuracy: 0.8672 - val_loss: 0.3932 - val_accuracy: 0.8584
# Epoch 3/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3299 - accuracy: 0.8788 - val_loss: 0.3638 - val_accuracy: 0.8686
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3080 - accuracy: 0.8862 - val_loss: 0.3593 - val_accuracy: 0.8730
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2905 - accuracy: 0.8932 - val_loss: 0.3531 - val_accuracy: 0.8719
# Epoch 6/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2770 - accuracy: 0.8969 - val_loss: 0.3602 - val_accuracy: 0.8751
# Epoch 7/20
# ...
